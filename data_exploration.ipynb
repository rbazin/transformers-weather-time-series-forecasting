# %% [markdown]
# # Exploration of the training set

# %%
import pandas as pd
import seaborn as sns

# %%
train_df = pd.read_csv('weather_train.csv', index_col='Date Time', parse_dates=True)

# %%
train_df.head()
# Out:
#                      p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  \
# Date Time
# 2009-01-01 01:00:00    996.50     -8.05    265.38        -8.78    94.4
# 2009-01-01 02:00:00    996.62     -8.88    264.54        -9.77    93.2
# 2009-01-01 03:00:00    996.84     -8.81    264.59        -9.66    93.5
# 2009-01-01 04:00:00    996.99     -9.05    264.34       -10.02    92.6
# 2009-01-01 05:00:00    997.46     -9.63    263.72       -10.65    92.2
#
#                      VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# Date Time
# 2009-01-01 01:00:00          3.33          3.14          0.19       1.96
# 2009-01-01 02:00:00          3.12          2.90          0.21       1.81
# 2009-01-01 03:00:00          3.13          2.93          0.20       1.83
# 2009-01-01 04:00:00          3.07          2.85          0.23       1.78
# 2009-01-01 05:00:00          2.94          2.71          0.23       1.69
#
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 56072 entries, 2009-01-01 01:00:00 to 2015-05-24 18:00:00
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   p (mbar)         56072 non-null  float64
#  1   T (degC)         56072 non-null  float64
#  2   Tpot (K)         56072 non-null  float64
#  3   Tdew (degC)      56072 non-null  float64
#  4   rh (%)           56072 non-null  float64
#  5   VPmax (mbar)     56072 non-null  float64
#  6   VPact (mbar)     56072 non-null  float64
#  7   VPdef (mbar)     56072 non-null  float64
#  8   sh (g/kg)        56072 non-null  float64
#  9   H2OC (mmol/mol)  56072 non-null  float64
#  10  rho (g/m**3)     56072 non-null  float64
#  11  wv (m/s)         56072 non-null  float64
#  12  max. wv (m/s)    56072 non-null  float64
#  13  wd (deg)         56072 non-null  float64
# dtypes: float64(14)
# memory usage: 6.4 MB

# %%
train_df.describe()
# Out:
#            p (mbar)      T (degC)      Tpot (K)   Tdew (degC)        rh (%)  \
# count  56072.000000  56072.000000  56072.000000  56072.000000  56072.000000
# mean     988.832928      8.987746    283.059875      4.551409     76.208224
# std        8.350194      8.440986      8.518036      6.830787     16.498261
# min      913.600000    -22.760000    250.850000    -24.800000     13.880000
# 25%      983.810000      2.880000    277.000000     -0.120000     65.497500
# 50%      989.240000      8.970000    283.100000      4.745000     79.500000
# 75%      994.310000     15.070000    289.130000      9.732500     89.600000
# max     1013.910000     35.650000    309.730000     23.060000    100.000000
#
#        VPmax (mbar)  VPact (mbar)  VPdef (mbar)     sh (g/kg)  \
# count  56072.000000  56072.000000  56072.000000  56072.000000
# mean      13.170791      9.297106      3.873606      5.874655
# std        7.479040      4.150333      4.673326      2.634644
# ...

# %%
# plot the temperature against date time. Only the years should be plotted
train_df.plot(y='T (degC)')
# Out:
# <Axes: xlabel='Date Time'>
